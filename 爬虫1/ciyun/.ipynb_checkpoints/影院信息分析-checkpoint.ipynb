# %%
import numpy as np
import pandas as pd
from wordcloud import WordCloud
import jieba
import matplotlib.pyplot as plt

# %%
# 读取文件
text = open('1234.txt','r',encoding='utf-8').read()

# %%
# 分割歌词
cut_text = jieba.cut(text)
print(cut_text)
# Out:
# <generator object Tokenizer.cut at 0x0000016B50B836D8>

# %%
# 拼接
result = " ".join(cut_text)
print(result)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\11716\AppData\Local\Temp\jieba.cache
# Loading model cost 0.997 seconds.
# Prefix dict has been built succesfully.
# ﻿ 致橡树
#
#  我 如果 爱 你 — —
#
#  绝不 像 攀援 的 凌霄花 ，
#
#  借 你 的 高枝 炫耀 自己 ；
#
#  我 如果 爱 你 — —
#
#  绝不 学 痴情 的 鸟儿 ，
#
#  为 绿荫 重复 单调 的 歌曲 ；
#
#  也 不止 像 泉源 ，
#
#  常年 送来 清凉 的 慰藉 ；
#
#  也 不止 像 险峰 ，
#
#  增加 你 的 高度 ， 衬托 你 的 威仪 。
#
#  甚至 日光 ，
#
#  甚至 春雨 。
#
#  不 ， 这些 都 还 不够 ！
#
#  我 必须 是 你 近旁 的 一株 木棉 ，
#
#  作为 树 的 形象 和 你 站 在 一起 。
#
#  根 ， 紧握 在 地下 ；
#
#  叶 ， 相触 在 云里 。
#
#  每 一阵风 过 ，
#
#  我们 都 互相 致意 ，
#
#  但 没有 人 ，
#
#  听懂 我们 的 言语 。
#
#  你 有 你 的 铜枝 铁干 ，
#
#  像 刀 ， 像 剑 ， 也 像 戟 ；
#
#  我 有 我 红硕 的 花朵 ，
#
#  像 沉重 的 叹息 ，
#
#  又 像 英勇 的 火炬 。
#
#  我们 分担 寒潮 、 风雷 、 霹雳 ；
#
#  我们 共享 雾霭 、 流岚 、 虹霓 。
#
#  仿佛 永远 分离 ，
#
#  却 又 终身 相依 。
#
#  这才 是 伟大 的 爱情 ，
#
#  坚贞 就 在 这里 ：
#
#  爱 — —
#
#  不仅 爱 你 伟岸 的 身躯 ，
#
#  也 爱 你 坚持 的 位置 ，
#
#  足下 的 土地 。

# %%
# 生成词云
wordc = WordCloud(font_path='simhei.ttf',
                 background_color='white',
                 width = 300,
                 height=200,
                 max_font_size=50,
                 min_font_size=10,
                  max_words=1000,
                 mask=plt.imread("3.png")
    
                 )
wordc.generate(result)
wordc.to_file('jielun.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-e5ac6c4c4f47> in <module>()
#       7                  min_font_size=10,
#       8                   max_words=1000,
# ----> 9                  mask=plt.imread("3.png")
#      10
#      11                  )
#
# D:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(*args, **kwargs)
#    2371 @docstring.copy_dedent(_imread)
#    2372 def imread(*args, **kwargs):
# -> 2373     return _imread(*args, **kwargs)
#    2374
#    2375
#
# D:\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1374             return handler(fd)
#    1375         else:
# -> 1376             with open(fname, 'rb') as fd:
#    1377                 return handler(fd)
#    1378     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '3.png'

# %%
# 显示图片
plt.figure('致橡树')
plt.imshow(wordc)
plt.axis('off')
plt.show()
